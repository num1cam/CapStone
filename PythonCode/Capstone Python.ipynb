# %%
import pandas as pd

# Loading the files to examine their contents
file_paths = {
    'GaCounty2023': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCounty 2023.csv",
    'GaCountyActive': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCounty Active.csv",
    'GaCountyContract': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCounty contract.csv",
    'GaCountyCondos23Sales': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCountyCondos23Sales.csv",
    'GaCountyCondosActive': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCountyCondosAl.csv",
    'GaCountyCondosUnderContract': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCountyCondosUc.csv",
    'TownhomeActive': r"C:\Users\aries\code\savvycoders\Capstone\All Data\TownhomeAc.csv",
    'TownhomeUnderContract': r"C:\Users\aries\code\savvycoders\Capstone\All Data\TownhomeUc.csv"
}

# Reading each file into a DataFrame
dataframes = {}

# Displaying the first few rows of each DataFrame to understand their structure
for name, df in dataframes.items():
    print(f"{name}:")
    display(df.head())
    print("\n")

# %%
import pandas as pd

# File paths
file_paths = {
    'GaCounty2023': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCounty 2023.csv",
    'GaCountyActive': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCounty Active.csv",
    'GaCountyContract': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCounty contract.csv",
    'GaCountyCondos23Sales': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCountyCondos23Sales.csv",
    'GaCountyCondosActive': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCountyCondosAl.csv",
    'GaCountyCondosUnderContract': r"C:\Users\aries\code\savvycoders\Capstone\All Data\GaCountyCondosUc.csv",
    'TownhomeActive': r"C:\Users\aries\code\savvycoders\Capstone\All Data\TownhomeAc.csv",
    'TownhomeUnderContract': r"C:\Users\aries\code\savvycoders\Capstone\All Data\TownhomeUc.csv"
}


# Load and display the first few rows of each file to understand their structure
dataframes = {}
for name, path in file_paths.items():
    dataframes[name] = pd.read_csv(path)

# Display the first few rows of each dataframe
dataframes_preview = {name: df.head() for name, df in dataframes.items()}
# dataframes_preview
dataframes
# Out:
# {'GaCounty2023':            County  Solds Ave List Price Ave Sold Price  Unnamed: 4
#  0     Al Counties      2       $166,000       $170,500         NaN
#  1         Appling      5       $193,380       $182,500         NaN
#  2           Bacon      1        $37,500        $30,000         NaN
#  3         Baldwin     24       $352,065       $341,204         NaN
#  4    Baldwin (AL)      0             $0             $0         NaN
#  ..            ...    ...            ...            ...         ...
#  163     Whitfield      3       $170,500       $170,667         NaN
#  164        Wilcox      0             $0             $0         NaN
#  165        Wilkes      0             $0             $0         NaN
#  166     Wilkinson      4       $117,725       $104,725         NaN
#  167         Worth      2       $185,000       $172,500         NaN
#
#  [168 rows x 5 columns],
#  'GaCountyActive':            County Number Ave List Price
#  0     Al Counties     15       $382,290
# ...
